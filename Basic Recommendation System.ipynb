# %% [markdown]
# # Basic recommendation system useing weighted average method
# ## This method is old school and is based on voting average and popularity

# %%
##importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#lets take up the datasets
movies=pd.read_csv("tmdb_5000_movies.csv")
credits=pd.read_csv("tmdb_5000_credits.csv")

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies.shape##has 20 columns
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.shape##has 4 columns
# Out:
# (4803, 4)

# %%
##we should combine the two datasets based on a particular column
##movie id and id are similar
credits=credits.rename(index=str,columns={"movie_id":"id"})

# %%
movies=movies.merge(credits,on="id")

# %%
movies.shape##we combined the two datasets
# Out:
# (4803, 23)

# %%
##in that datasets we donot need a few columns
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
##irrelavant=[homepage,production_countries,title_x,title_y,status]
movies=movies.drop(columns=["homepage","production_countries","title_x","title_y","status"])

# %%
movies.shape
# Out:
# (4803, 18)

# %%
movies.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
##check for null values
movies.isnull().sum()
# Out:
# budget                    0
# genres                    0
# id                        0
# keywords                  0
# original_language         0
# original_title            0
# overview                  3
# popularity                0
# production_companies      0
# release_date              1
# revenue                   0
# runtime                   2
# spoken_languages          0
# tagline                 844
# vote_average              0
# vote_count                0
# cast                      0
# crew                      0
# dtype: int64

# %% [markdown]
# # WEIGHTED AVERAGE SYSTEM

# %%
##w=(r*v+c*m)/(v+m)
#w=weighted average
#r=average votes(0-10)
#v=total no. of votes
#m=minimum no of votes required 
#c=mean of the average votes

# %%
r=movies["vote_average"]
v=movies["vote_count"]
c=movies["vote_average"].mean()
m=movies["vote_count"].quantile(0.70)##this will only select those which has 70% or more no of votes

# %%
weighted_average=(r*v+c*m)/(v+m)

# %%
movies["weighted_average"]=weighted_average

# %%
movies.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
movies=movies.sort_values("weighted_average", ascending=False)

# %%
movies[['original_title', 'vote_count', 'vote_average', 'weighted_average', 'popularity']].head(20)
# Out:
#                                          original_title  vote_count  \
# 1881                           The Shawshank Redemption        8205
# 3337                                      The Godfather        5893
# 662                                          Fight Club        9413
# 3232                                       Pulp Fiction        8428
# 65                                      The Dark Knight       12002
# 809                                        Forrest Gump        7927
# 1818                                   Schindler's List        4329
# 3865                                           Whiplash        4254
# 96                                            Inception       13752
# 1990                            The Empire Strikes Back        5879
# 2294                                           千と千尋の神隠し        3840
# 95                                         Interstellar       10867
# 2731                             The Godfather: Part II        3338
# ...

# %%
##this recommendation is based on votes
##we can check for popularity as well
##since many popular movies are unrated too
popularity=movies.sort_values("popularity",ascending=False)

# %%
popularity.head()
# Out:
#         budget                                             genres      id  \
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...  157336
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  293660
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...  118340
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   76341
#
#                                               keywords original_language  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
# 95   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 788  [{"id": 2095, "name": "anti hero"}, {"id": 307...                en
# 94   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 127  [{"id": 2964, "name": "future"}, {"id": 3713, ...                en
#
#               original_title  \
# 546                  Minions
# ...

# %%
#lets plot based on popularity and votes
plt.figure(figsize=(12,6))
ax=sns.barplot(x=popularity['popularity'].head(10), y=popularity['original_title'].head(10), data=popularity)

plt.title('Most Popular by Votes', weight='bold')
plt.xlabel('Score of Popularity', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_popular_movies.png')

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(x=movies['weighted_average'].head(10), y=movies['original_title'].head(10), data=movies)

plt.title('Most Popular by Votes', weight='bold')
plt.xlabel('weighted score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_popular_movies.png')

# %%
##we see two dfferent sorts of recommendations so we will build a system giving 50% of weightage to both votes and popularity

# %% [markdown]
# ## Recommendation based on scaled weighted average and popularity score(Priority is given 50% to both)

# %%
movies.head()
# Out:
#          budget                                             genres   id  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...  278
# 3337    6000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...  238
# 662    63000000                      [{"id": 18, "name": "Drama"}]  550
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...  680
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...  155
#
#                                                keywords original_language  \
# 1881  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
# 3337  [{"id": 131, "name": "italy"}, {"id": 699, "na...                en
# 662   [{"id": 825, "name": "support group"}, {"id": ...                en
# 3232  [{"id": 396, "name": "transporter"}, {"id": 14...                en
# 65    [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                 original_title  \
# 1881  The Shawshank Redemption
# ...

# %%
#there is a huge difference between the popularity and weighted_avearge so we need to scale it down
from sklearn.preprocessing import MinMaxScaler

scaling=MinMaxScaler()
movie_scaled=scaling.fit_transform(movies[['weighted_average','popularity']])
movie_normalized=pd.DataFrame(movie_scaled,columns=['weighted_average','popularity'])
movie_normalized.head()
# Out:
#    weighted_average  popularity
# 0          1.000000    0.156179
# 1          0.959622    0.164074
# 2          0.953823    0.167611
# 3          0.949991    0.138723
# 4          0.934991    0.213941

# %%
movies[['normalized_weight_average','normalized_popularity']]= movie_normalized##adding the scaled values as two feature

# %%
movies.head()
# Out:
#          budget                                             genres   id  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...  278
# 3337    6000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...  238
# 662    63000000                      [{"id": 18, "name": "Drama"}]  550
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...  680
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...  155
#
#                                                keywords original_language  \
# 1881  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
# 3337  [{"id": 131, "name": "italy"}, {"id": 699, "na...                en
# 662   [{"id": 825, "name": "support group"}, {"id": ...                en
# 3232  [{"id": 396, "name": "transporter"}, {"id": 14...                en
# 65    [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                 original_title  \
# 1881  The Shawshank Redemption
# ...

# %%
##giving 50-50 to both popularity and weighted_average
movies['score'] = movies['normalized_weight_average'] * 0.5 + movies['normalized_popularity'] * 0.5
movies= movies.sort_values(['score'], ascending=False)
movies[['original_title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                    original_title  normalized_weight_average  \
# 11                              Quantum of Solace                   0.906439
# 1071                                      Blended                   0.460630
# 29                                        Skyfall                   0.851874
# 135                                   The Wolfman                   0.725217
# 210                                Batman & Robin                   0.670973
# 0                                          Avatar                   1.000000
# 4                                     John Carter                   0.934991
# 7                         Avengers: Age of Ultron                   0.916431
# 1        Pirates of the Caribbean: At World's End                   0.959622
# 2                                         Spectre                   0.953823
# 8          Harry Potter and the Half-Blood Prince                   0.912039
# ...

# %%
##now lets plot based on the score

scored= movies.sort_values('score', ascending=False)

plt.figure(figsize=(16,6))

ax = sns.barplot(x=scored['score'].head(10), y=scored['original_title'].head(10), data=scored, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')

plt.savefig('scored_movies.png')
